# %%
import pandas as pd

# %%
pd.read_csv('table_1_data.csv')
# Out:
#   MDD VerticaFare Tracking ID Dynamic Fare Tracking ID  \
# 0                 ALL60431240              ALL54330180
#
#   Histogram Fare Tracking ID Fares Strip Fare Tracking ID  \
# 0                ALL62332760                  ALL59705690
#
#           Boxever Tracking ID Boxever ML Tracking ID  \
# 0  ALL21786150 (DefaultValue)            ALL11101210
#
#    Homepage Fares Tracking ID  Boxever Offers Tracking ID  \
# 0  ALL75955700 (DefaultValue)  ALL65919200 (DefaultValue)
#
#             Header Checkin ID    Manage Booking Checkin ID  \
# 0  ALL50312570 (DefaultValue)  ALL54261150 (Default Value)
#
#                 BPG Desktop ID BPG Mobile ID Complement Journey Link IID  \
# 0  ALL29548590 (Default Value)   ALL40778730                 ALL96603970
#
#    Search Results - Manage Booking IID  New Destinationprice Discover cta IID  \
# 0                                  NaN                                    NaN
#
#    Content Strip Manual Fares IID  Content Strip Dynamic Fares IID
# ...

# %%
df1 = pd.read_csv('table_2_data.csv')
df1
# Out:
#                 Economy Lite            Economy Classic  \
# 0                20kg (44lb)                25kg (55lb)
# 1  1 piece\n(23kg/50lb each)  2 pieces (23kg/50lb each)
# 2         1 piece (7kg/15lb)         1 piece (7kg/15lb)
#
#          Economy Convenience            Economy Comfort  \
# 0                30kg (66lb)                35kg (77lb)
# 1  2 pieces (23kg/50lb each)  2 pieces (23kg/50lb each)
# 2         1 piece (7kg/15lb)         1 piece (7kg/15lb)
#
#    Flights to/from all destinations  Flights to/from Africa or Americas  \
# 0                               NaN                                 NaN
# 1                               NaN                                 NaN
# 2                               NaN                                 NaN
#
#    Hand baggage
# 0           NaN
# 1           NaN
# 2           NaN

# %%
df2 = pd.read_csv('table_3_data.csv')
df2
# Out:
#                         Business Lite            Business Classic  \
# 0    Flights to/from all destinations                 40kg (88lb)
# 1  Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# 2                        Hand baggage  2 pieces (15kg/33lb total)
#
#              Business Comfort              Business Elite
# 0                 40kg (88lb)                 40kg (88lb)
# 1   2 pieces (32kg/70lb each)   2 pieces (32kg/70lb each)
# 2  2 pieces (15kg/33lb total)  2 pieces (15kg/33lb total)

# %%
df3 = pd.read_csv('table_4_data.csv')
df3
# Out:
#                   First Elite  Flights to/from all destinations  \
# 0                50kg (110lb)                               NaN
# 1   2 pieces (32kg/70lb each)                               NaN
# 2  2 pieces (15kg/33lb total)                               NaN
#
#    Flights to/from Africa or Americas  Hand baggage
# 0                                 NaN           NaN
# 1                                 NaN           NaN
# 2                                 NaN           NaN

# %%
new_index = ['Flights to/from all destinations', 
             'Flights to/from Africa or Americas', 
             'Hand baggage']
df1.index = new_index
df1
# Out:
#                                                  Economy Lite  \
# Flights to/from all destinations                  20kg (44lb)
# Flights to/from Africa or Americas  1 piece\n(23kg/50lb each)
# Hand baggage                               1 piece (7kg/15lb)
#
#                                               Economy Classic  \
# Flights to/from all destinations                  25kg (55lb)
# Flights to/from Africa or Americas  2 pieces (23kg/50lb each)
# Hand baggage                               1 piece (7kg/15lb)
#
#                                           Economy Convenience  \
# Flights to/from all destinations                  30kg (66lb)
# Flights to/from Africa or Americas  2 pieces (23kg/50lb each)
# Hand baggage                               1 piece (7kg/15lb)
#
#                                               Economy Comfort  \
# Flights to/from all destinations                  35kg (77lb)
# Flights to/from Africa or Americas  2 pieces (23kg/50lb each)
# ...

# %%
df1.drop(columns=['Flights to/from all destinations',
       'Flights to/from Africa or Americas', 'Hand baggage'] , inplace = True)

# %%
df1
# Out:
#                                                  Economy Lite  \
# Flights to/from all destinations                  20kg (44lb)
# Flights to/from Africa or Americas  1 piece\n(23kg/50lb each)
# Hand baggage                               1 piece (7kg/15lb)
#
#                                               Economy Classic  \
# Flights to/from all destinations                  25kg (55lb)
# Flights to/from Africa or Americas  2 pieces (23kg/50lb each)
# Hand baggage                               1 piece (7kg/15lb)
#
#                                           Economy Convenience  \
# Flights to/from all destinations                  30kg (66lb)
# Flights to/from Africa or Americas  2 pieces (23kg/50lb each)
# Hand baggage                               1 piece (7kg/15lb)
#
#                                               Economy Comfort
# Flights to/from all destinations                  35kg (77lb)
# Flights to/from Africa or Americas  2 pieces (23kg/50lb each)
# ...

# %%
df1.to_json('Economy_Class_Updated.json', orient="records", lines=False, indent=4)

# %%
df2
# Out:
#                         Business Lite            Business Classic  \
# 0    Flights to/from all destinations                 40kg (88lb)
# 1  Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# 2                        Hand baggage  2 pieces (15kg/33lb total)
#
#              Business Comfort              Business Elite
# 0                 40kg (88lb)                 40kg (88lb)
# 1   2 pieces (32kg/70lb each)   2 pieces (32kg/70lb each)
# 2  2 pieces (15kg/33lb total)  2 pieces (15kg/33lb total)

# %%
df2['Business Lite'][0] = '40kg (88lb)'
df2['Business Lite'][1] = '2 pieces (32kg/70lb each)'
df2['Business Lite'][2] = '2 pieces (15kg/33lb total)'
# Out:
# C:\Users\Mayur Dalvi\AppData\Local\Temp\ipykernel_17504\598908898.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df2['Business Lite'][0] = '40kg (88lb)'
# ...

# %%
df2
# Out:
#                 Business Lite            Business Classic  \
# 0                 40kg (88lb)                 40kg (88lb)
# 1   2 pieces (32kg/70lb each)   2 pieces (32kg/70lb each)
# 2  2 pieces (15kg/33lb total)  2 pieces (15kg/33lb total)
#
#              Business Comfort              Business Elite
# 0                 40kg (88lb)                 40kg (88lb)
# 1   2 pieces (32kg/70lb each)   2 pieces (32kg/70lb each)
# 2  2 pieces (15kg/33lb total)  2 pieces (15kg/33lb total)

# %%
new_index = ['Flights to/from all destinations', 
             'Flights to/from Africa or Americas', 
             'Hand baggage']
df2.index = new_index
df2
# Out:
#                                                  Business Lite  \
# Flights to/from all destinations                   40kg (88lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# Hand baggage                        2 pieces (15kg/33lb total)
#
#                                               Business Classic  \
# Flights to/from all destinations                   40kg (88lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# Hand baggage                        2 pieces (15kg/33lb total)
#
#                                               Business Comfort  \
# Flights to/from all destinations                   40kg (88lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# Hand baggage                        2 pieces (15kg/33lb total)
#
#                                                 Business Elite
# Flights to/from all destinations                   40kg (88lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# ...

# %%
df2.to_json('Business_Class_Updated.json', orient="records", lines=False, indent=4)

# %%
df3
# Out:
#                   First Elite  Flights to/from all destinations  \
# 0                50kg (110lb)                               NaN
# 1   2 pieces (32kg/70lb each)                               NaN
# 2  2 pieces (15kg/33lb total)                               NaN
#
#    Flights to/from Africa or Americas  Hand baggage
# 0                                 NaN           NaN
# 1                                 NaN           NaN
# 2                                 NaN           NaN

# %%
new_index = ['Flights to/from all destinations', 
             'Flights to/from Africa or Americas', 
             'Hand baggage']
df3.index = new_index

# %%
df3
# Out:
#                                                    First Elite  \
# Flights to/from all destinations                  50kg (110lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# Hand baggage                        2 pieces (15kg/33lb total)
#
#                                     Flights to/from all destinations  \
# Flights to/from all destinations                                 NaN
# Flights to/from Africa or Americas                               NaN
# Hand baggage                                                     NaN
#
#                                     Flights to/from Africa or Americas  \
# Flights to/from all destinations                                   NaN
# Flights to/from Africa or Americas                                 NaN
# Hand baggage                                                       NaN
#
#                                     Hand baggage
# Flights to/from all destinations             NaN
# ...

# %%
df3.drop(columns=['Flights to/from all destinations',
       'Flights to/from Africa or Americas', 'Hand baggage'] , inplace = True)

# %%
df3.to_json('First_Class_Updated.json', orient="records", lines=False, indent=4)

# %%
df1
# Out:
#                                                  Economy Lite  \
# Flights to/from all destinations                  20kg (44lb)
# Flights to/from Africa or Americas  1 piece\n(23kg/50lb each)
# Hand baggage                               1 piece (7kg/15lb)
#
#                                               Economy Classic  \
# Flights to/from all destinations                  25kg (55lb)
# Flights to/from Africa or Americas  2 pieces (23kg/50lb each)
# Hand baggage                               1 piece (7kg/15lb)
#
#                                           Economy Convenience  \
# Flights to/from all destinations                  30kg (66lb)
# Flights to/from Africa or Americas  2 pieces (23kg/50lb each)
# Hand baggage                               1 piece (7kg/15lb)
#
#                                               Economy Comfort
# Flights to/from all destinations                  35kg (77lb)
# Flights to/from Africa or Americas  2 pieces (23kg/50lb each)
# ...

# %%
df2
# Out:
#                                                  Business Lite  \
# Flights to/from all destinations                   40kg (88lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# Hand baggage                        2 pieces (15kg/33lb total)
#
#                                               Business Classic  \
# Flights to/from all destinations                   40kg (88lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# Hand baggage                        2 pieces (15kg/33lb total)
#
#                                               Business Comfort  \
# Flights to/from all destinations                   40kg (88lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# Hand baggage                        2 pieces (15kg/33lb total)
#
#                                                 Business Elite
# Flights to/from all destinations                   40kg (88lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# ...

# %%
df3
# Out:
#                                                    First Elite
# Flights to/from all destinations                  50kg (110lb)
# Flights to/from Africa or Americas   2 pieces (32kg/70lb each)
# Hand baggage                        2 pieces (15kg/33lb total)

# %% [markdown]
# # Preprocessing is done . now i am able to scrap the same data which was present in the url
